#
#                                                 img_path  \
# 0      ../data/dog_breed_data/Images/n02085620-Chihua...
# 1      ../data/dog_breed_data/Images/n02085620-Chihua...
# 2      ../data/dog_breed_data/Images/n02085620-Chihua...
# 3      ../data/dog_breed_data/Images/n02085620-Chihua...
# 4      ../data/dog_breed_data/Images/n02085620-Chihua...
# ...                                                  ...
# 12047  ../data/dog_breed_data/Images/n02085620-Chihua...
# 12048  ../data/dog_breed_data/Images/n02085620-Chihua...
# 12049  ../data/dog_breed_data/Images/n02085620-Chihua...
# 12050  ../data/dog_breed_data/Images/n02085620-Chihua...
# 12051  ../data/dog_breed_data/Images/n02085620-Chihua...
#
#                                                 ann_path                breed  \
# 0      ../data/dog_breed_data/Annotations/n02085620-C...  n02085620-Chihuahua
# 1      ../data/dog_breed_data/Annotations/n02085620-C...  n02085620-Chihuahua
# 2      ../data/dog_breed_data/Annotations/n02085620-C...  n02085620-Chihuahua
# 3      ../data/dog_breed_data/Annotations/n02085620-C...  n02085620-Chihuahua
# 4      ../data/dog_breed_data/Annotations/n02085620-C...  n02085620-Chihuahua
# ...                                                  ...                  ...
# 12047  ../data/dog_breed_data/Annotations/n02085620-C...  n02085620-Chihuahua
# 12048  ../data/dog_breed_data/Annotations/n02085620-C...  n02085620-Chihuahua
# 12049  ../data/dog_breed_data/Annotations/n02085620-C...  n02085620-Chihuahua
# 12050  ../data/dog_breed_data/Annotations/n02085620-C...  n02085620-Chihuahua
# 12051  ../data/dog_breed_data/Annotations/n02085620-C...  n02085620-Chihuahua
#
#        gid
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
# ...    ...
# 12047    0
# 12048    0
# 12049    0
# 12050    0
# 12051    0
#
# [152 rows x 6 columns]

# %%
df.head(100)
# Out:
#     split                                 rel_path  \
# 0   train   n02085620-Chihuahua/n02085620_5927.jpg
# 1   train   n02085620-Chihuahua/n02085620_4441.jpg
# 2   train   n02085620-Chihuahua/n02085620_1502.jpg
# 3   train   n02085620-Chihuahua/n02085620_1916.jpg
# 4   train  n02085620-Chihuahua/n02085620_13151.jpg
# ..    ...                                      ...
# 95  train   n02085620-Chihuahua/n02085620_4875.jpg
# 96  train   n02085620-Chihuahua/n02085620_2693.jpg
# 97  train  n02085620-Chihuahua/n02085620_14516.jpg
# 98  train   n02085620-Chihuahua/n02085620_1298.jpg
# 99  train   n02085620-Chihuahua/n02085620_1346.jpg
#
#                                              img_path  \
# 0   ../data/dog_breed_data/Images/n02085620-Chihua...
# 1   ../data/dog_breed_data/Images/n02085620-Chihua...
# 2   ../data/dog_breed_data/Images/n02085620-Chihua...
# 3   ../data/dog_breed_data/Images/n02085620-Chihua...
# 4   ../data/dog_breed_data/Images/n02085620-Chihua...
# ..                                                ...
# 95  ../data/dog_breed_data/Images/n02085620-Chihua...
# 96  ../data/dog_breed_data/Images/n02085620-Chihua...
# 97  ../data/dog_breed_data/Images/n02085620-Chihua...
# 98  ../data/dog_breed_data/Images/n02085620-Chihua...
# 99  ../data/dog_breed_data/Images/n02085620-Chihua...
#
#                                              ann_path                breed  \
# 0   ../data/dog_breed_data/Annotations/n02085620-C...  n02085620-Chihuahua
# 1   ../data/dog_breed_data/Annotations/n02085620-C...  n02085620-Chihuahua
# 2   ../data/dog_breed_data/Annotations/n02085620-C...  n02085620-Chihuahua
# 3   ../data/dog_breed_data/Annotations/n02085620-C...  n02085620-Chihuahua
# 4   ../data/dog_breed_data/Annotations/n02085620-C...  n02085620-Chihuahua
# ..                                                ...                  ...
# 95  ../data/dog_breed_data/Annotations/n02085620-C...  n02085620-Chihuahua
# 96  ../data/dog_breed_data/Annotations/n02085620-C...  n02085620-Chihuahua
# 97  ../data/dog_breed_data/Annotations/n02085620-C...  n02085620-Chihuahua
# 98  ../data/dog_breed_data/Annotations/n02085620-C...  n02085620-Chihuahua
# 99  ../data/dog_breed_data/Annotations/n02085620-C...  n02085620-Chihuahua
#
#     gid
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0
# ..  ...
# 95    0
# 96    0
# 97    0
# 98    0
# 99    0
#
# [100 rows x 6 columns]

# %%
df[df.isna().any(axis=1)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df[df.isna().any(axis=1)]
#
# NameError: name 'df' is not defined

# %%
df[(df["DogID"] == 16) & (df["Behavior_1"] == "Sitting")]
# Out:
#         DogID  TestNum   t_sec   ABack_x   ABack_y   ABack_z   ANeck_x  \
# 32369      16        1  323.69  0.280273 -0.684082  0.691406 -0.212891
# 32370      16        1  323.70  0.282715 -0.682617  0.692383 -0.210449
# 32371      16        1  323.71  0.280762 -0.677734  0.692871 -0.207520
# 32372      16        1  323.72  0.275879 -0.673828  0.689941 -0.206055
# 32373      16        1  323.73  0.274902 -0.673828  0.685059 -0.203125
# ...       ...      ...     ...       ...       ...       ...       ...
# 256967     16        2  929.63  0.376953 -0.532715  0.625000 -0.083008
# 256968     16        2  929.64  0.403320 -0.577637  0.644043 -0.066406
# 256969     16        2  929.65  0.433105 -0.636230  0.722168 -0.100586
# 256970     16        2  929.66  0.468750 -0.750977  0.680664 -0.170898
# 256971     16        2  929.67  0.504883 -0.905762  0.669434 -0.246094
#
#          ANeck_y   ANeck_z    GBack_x   GBack_y   GBack_z    GNeck_x  \
# 32369  -0.985352 -0.131836  -1.281738  0.671387 -2.319336   3.173828
# 32370  -0.991699 -0.122559  -1.342774  0.427246 -2.014160   3.417969
# 32371  -0.989258 -0.113281  -1.403809  0.488281 -1.770020   4.150391
# 32372  -0.978516 -0.114258  -1.586914  0.366211 -1.708984   4.760742
# 32373  -0.968750 -0.126953  -2.075195  0.122070 -1.770020   4.821778
# ...          ...       ...        ...       ...       ...        ...
# 256967 -1.163574 -0.263184 -27.526857  1.892090  1.403809 -38.391116
# 256968 -1.226563 -0.220703 -31.250002 -2.502442 -1.525879 -33.020022
# 256969 -1.226074 -0.222168 -35.278322 -4.577637 -4.150391 -27.709963
# 256970 -1.167969 -0.269531 -38.818362 -6.164551 -4.272461 -28.991701
# 256971 -1.090332 -0.327148 -43.640139 -5.737305 -5.004883 -36.560061
#
#           GNeck_y   GNeck_z         Task Behavior_1   Behavior_2   Behavior_3  \
# 32369    0.305176  0.305176     Task sit    Sitting  <undefined>  <undefined>
# 32370   -0.488281  0.610352     Task sit    Sitting  <undefined>  <undefined>
# 32371   -0.305176  0.549316     Task sit    Sitting  <undefined>  <undefined>
# 32372    0.610352  0.366211     Task sit    Sitting  <undefined>  <undefined>
# 32373    1.159668  0.244141     Task sit    Sitting  <undefined>  <undefined>
# ...           ...       ...          ...        ...          ...          ...
# 256967 -51.025394 -5.676270  <undefined>    Sitting  <undefined>  <undefined>
# 256968 -44.067386 -2.929688  <undefined>    Sitting  <undefined>  <undefined>
# 256969 -36.193850 -2.380371  <undefined>    Sitting  <undefined>  <undefined>
# 256970 -28.503420 -0.305176  <undefined>    Sitting  <undefined>  <undefined>
# 256971 -23.193361  6.530762  <undefined>    Sitting  <undefined>  <undefined>
#
#              Breed
# 32369   Crossbreed
# 32370   Crossbreed
# 32371   Crossbreed
# 32372   Crossbreed
# 32373   Crossbreed
# ...            ...
# 256967  Crossbreed
# 256968  Crossbreed
# 256969  Crossbreed
# 256970  Crossbreed
# 256971  Crossbreed
#
# [36693 rows x 20 columns]

# %%
# Assuming df has columns 'DogID' and 'TestNum'
dogs_with_both = (
    df.groupby("DogID")["TestNum"]
      .nunique()
      .reset_index(name="num_sessions")
)

# Keep only dogs with exactly 2 unique TestNums (1 and 2)
dogs_with_both = dogs_with_both[dogs_with_both["num_sessions"] >= 2]

print(f"Number of dogs with both TestNum 1 and 2: {len(dogs_with_both)}")
print(dogs_with_both)
# Out:
# Number of dogs with both TestNum 1 and 2: 17
#     DogID  num_sessions
# 0      16             2
# 6      23             2
# 7      25             2
# 8      26             2
# 9      27             2
# 11     29             2
# 12     30             2
# 14     34             2
# 16     39             2
# 17     41             2
# 18     43             2
# 20     45             2
# 21     46             2
# 22     47             2
# 23     48             2
# 24     49             2
# 44     74             2

# %%
dog_sessions = (
    df.groupby("DogID")["TestNum"]
      .unique()
      .reset_index(name="sessions")
)

print(dog_sessions)
# Out:
#     DogID sessions
# 0      16   [1, 2]
# 1      18      [1]
# 2      19      [2]
# 3      20      [1]
# 4      21      [1]
# 5      22      [2]
# 6      23   [1, 2]
# 7      25   [1, 2]
# 8      26   [1, 2]
# 9      27   [1, 2]
# 10     28      [1]
# 11     29   [1, 2]
# 12     30   [1, 2]
# 13     33      [1]
# 14     34   [1, 2]
# 15     36      [1]
# 16     39   [1, 2]
# 17     41   [1, 2]
# 18     43   [1, 2]
# 19     44      [1]
# 20     45   [1, 2]
# 21     46   [1, 2]
# 22     47   [1, 2]
# 23     48   [1, 2]
# 24     49   [1, 2]
# 25     51      [1]
# 26     52      [1]
# 27     53      [1]
# 28     54      [1]
# 29     55      [1]
# 30     56      [1]
# 31     57      [1]
# 32     58      [2]
# 33     59      [1]
# 34     60      [1]
# 35     61      [1]
# 36     63      [2]
# 37     65      [1]
# 38     66      [2]
# 39     67      [1]
# 40     68      [1]
# 41     70      [1]
# 42     72      [1]
# 43     73      [1]
# 44     74   [1, 2]

# %%
dog_47_1 = df[(df["DogID"] == 47)]
dog_47_1.head()
# Out:
#          DogID  TestNum  t_sec   ABack_x   ABack_y   ABack_z   ANeck_x  \
# 3910014     47        1   0.01 -0.143066  0.980957 -0.006836 -0.183105
# 3910015     47        1   0.02 -0.143555  0.978516 -0.010742 -0.127930
# 3910016     47        1   0.03 -0.146484  0.977539 -0.011719 -0.133301
# 3910017     47        1   0.04 -0.145996  0.979980 -0.013184 -0.180176
# 3910018     47        1   0.05 -0.140137  0.984375 -0.007324 -0.229492
#
#           ANeck_y   ANeck_z   GBack_x  ...   GBack_z    GNeck_x    GNeck_y  \
# 3910014 -0.834961 -0.555176  0.671387  ... -0.488281  12.390137  53.283695
# 3910015 -0.855957 -0.501953  0.244141  ... -0.183105  13.305665  63.110355
# 3910016 -0.858398 -0.508789  0.183105  ...  0.122070  14.587403  74.951176
# 3910017 -0.862793 -0.538574  0.549316  ...  0.244141  15.808106  80.078130
# 3910018 -0.834961 -0.518066  0.854492  ...  0.854492  22.338869  75.073247
#
#            GNeck_z         Task       Behavior_1   Behavior_2   Behavior_3  \
# 3910014  47.912601  <undefined>  Synchronization  <undefined>  <undefined>
# 3910015  54.504398  <undefined>  Synchronization  <undefined>  <undefined>
# 3910016  55.664066  <undefined>  Synchronization  <undefined>  <undefined>
# 3910017  52.856449  <undefined>  Synchronization  <undefined>  <undefined>
# 3910018  48.767093  <undefined>  Synchronization  <undefined>  <undefined>
#
#                         Breed Selected_Behavior
# 3910014  Bouvier des Ardennes              None
# 3910015  Bouvier des Ardennes              None
# 3910016  Bouvier des Ardennes              None
# 3910017  Bouvier des Ardennes              None
# 3910018  Bouvier des Ardennes              None
#
# [5 rows x 21 columns]

# %%
dog_47_1["Behavior_1"].value_counts()
# Out:
# Behavior_1
# Trotting           33000
# Sniffing           28934
# <undefined>        27081
# Lying chest        26956
# Walking            25970
# Panting            19572
# Eating             19253
# Playing            16490
# Standing           10498
# Sitting            10013
# Tugging             5366
# Drinking            2824
# Carrying object     2326
# Galloping           1835
# Shaking             1823
# Synchronization      514
# Jumping              295
# Bowing               275
# Pacing               199
# Name: count, dtype: int64

# %%
import numpy as np
import torch
def load_dog_data(df):
    """Load raw dog data with only 7 main behaviors."""
    print("Loading raw dog data...")
    
    
    
    # Select sensor columns
    sensor_cols = []
    
    sensor_cols.extend([col for col in df.columns if col.startswith('ABack_') or col.startswith('ANeck_')])

    sensor_cols.extend([col for col in df.columns if col.startswith('GBack_') or col.startswith('GNeck_')])

    print(f"Using {len(sensor_cols)} sensor columns")
    
    # Define the 7 main behaviors
    main_behaviors = [
        'Standing', 'Walking', 'Sitting', 'Lying on chest', 
        'Sniffing', 'Trotting', 'Galloping'
    ]
    
    # Create a function to select the best behavior from the 3 columns
    def select_behavior(row):
        """Select the best behavior from Behavior_1, Behavior_2, Behavior_3."""
        behaviors = [row['Behavior_1'], row['Behavior_2'], row['Behavior_3']]
        
        # Priority: Behavior_1 > Behavior_2 > Behavior_3
        for behavior in behaviors:
            if behavior != '<undefined>' and behavior in main_behaviors:
                return behavior
        
        # If no main behavior found, return None
        return None
    
    # Apply behavior selection
    df['Selected_Behavior'] = df.apply(select_behavior, axis=1)
    
    # Filter to only rows with valid behaviors
    df_filtered = df[df['Selected_Behavior'].notna()].copy()
    
    print(f"Behavior selection results:")
    print(f"  Total rows: {len(df)}")
    print(f"  Rows with valid behaviors: {len(df_filtered)}")
    print(f"  Rows dropped: {len(df) - len(df_filtered)}")
    
    # Get behavior counts using selected behavior
    behavior_counts = df_filtered['Selected_Behavior'].value_counts()
    print(f"Behavior counts after filtering:")
    for behavior, count in behavior_counts.items():
        print(f"  {behavior}: {count} samples")
    
    # Create behavior mapping - use consistent order for CIL
    backbone_behaviors = ['Standing', 'Walking', 'Sitting', 'Lying on chest']
    cil_behaviors = ['Sniffing', 'Trotting', 'Galloping']
    behaviors = backbone_behaviors + cil_behaviors  # Consistent order
    behavior_to_idx = {b: i for i, b in enumerate(behaviors)}
    print(f"Using {len(behaviors)} behaviors: {behaviors}")
    
    # Prepare data per dog
    dog_data = {}
    for dog_id in sorted(df_filtered['DogID'].unique()):
        dog_df = df_filtered[df_filtered['DogID'] == dog_id]
        
        # Sample data to manageable size
        if len(dog_df) > 10000:
            dog_df = dog_df.sample(n=10000, random_state=42)
        
        # Extract features and labels
        X = dog_df[sensor_cols].values.astype(np.float32)
        y = dog_df['Selected_Behavior'].map(behavior_to_idx).values
        
        # Normalize features
        X = (X - X.mean(axis=0)) / (X.std(axis=0) + 1e-8)
        
        dog_data[dog_id] = {
            'X': torch.from_numpy(X),
            'y': torch.from_numpy(y),
            'behaviors': sorted(dog_df['Selected_Behavior'].unique())
        }
    
    return dog_data, behavior_to_idx, behaviors

# %%
dog_data, behavior_to_idx, behaviors = load_dog_data(df)
# Out:
# Loading raw dog data...
# Using 12 sensor columns
# Behavior selection results:
#   Total rows: 6961682
#   Rows with valid behaviors: 4905844
#   Rows dropped: 2055838
# Behavior counts after filtering:
#   Sitting: 1120116 samples
#   Standing: 1027710 samples
#   Sniffing: 1026178 samples
#   Walking: 783035 samples
#   Trotting: 773879 samples
#   Galloping: 174926 samples
# Using 7 behaviors: ['Standing', 'Walking', 'Sitting', 'Lying on chest', 'Sniffing', 'Trotting', 'Galloping']

# %%
behavior_to_idx.get('Sitting')
# Out:
# 2

# %%
dog_data[16]['X'][0]
# Out:
# tensor([ 0.5507, -1.0398, -0.2928, -0.2064, -0.6354,  0.2394,  0.0337, -0.0070,
#         -0.0058, -0.0095, -0.0059,  0.0319])

# %%
dog_data[16]['y']
# Out:
# tensor([2, 1, 4,  ..., 2, 2, 2])
